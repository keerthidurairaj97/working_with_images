# %% [markdown]
# Imported the Necessary libraries below

# %%
import matplotlib.pyplot as plt
import skimage.io as io
import numpy as np

# %% [markdown]
# Read the image from skimage.io

# %%
i1=io.imread('i1.jpg')

# %% [markdown]
# Visualize the image using matplotlib

# %%
plt.imshow(i1)
plt.show()

# %%
print("Shape of the input image",i1.shape)
# Out:
# Shape of the input image (1170, 1880, 3)

# %% [markdown]
# Extraction image with particular RGB channels.

# %%
red=i1[:,:,0]
green=i1[:,:,1]
blue=i1[:,:,2]

# %% [markdown]
# Extracted RED channel image

# %%
plt.imshow(red,cmap='Reds')
plt.show()

# %% [markdown]
# Extracted GREEN channel image

# %%
plt.imshow(g,cmap='Greens')
plt.show()

# %% [markdown]
# Extracted BLUE channel image

# %%
plt.imshow(g,cmap='Blues')
plt.show()
